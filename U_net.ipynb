# %% [markdown]
# <a href="https://colab.research.google.com/github/shb8086/Cancer/blob/main/U_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
# !pip install unrar
import os
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/bb/0b/53130ccd483e3db8c8a460cb579bdb21b458d5494d67a261e1a5b273fbb9/unrar-0.4-py3-none-any.whl
# ...

# %%
# !gdown --id 1NBVeBpL9XjI6cGUTkq9WQxjJ8WPxuxV2
# !unrar x -Y "/content/dataset.rar"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NBVeBpL9XjI6cGUTkq9WQxjJ8WPxuxV2
# To: /content/dataset.rar
# 101MB [00:00, 244MB/s]
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/dataset.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
from PIL import Image
path='/content/dataset/annotations_prepped_test/'
for i in range(1,781):
    p=path+str(i)+'.png'
    if(os.path.isfile(p)):
      im = Image.open(p)
      im = im.resize((512, 512))
      im.save(path+str(i)+'.png', 'PNG')

# %%
path='/content/dataset/annotations_prepped_train/'
for i in range(1,781):
    p=path+str(i)+'.png'
    if(os.path.isfile(p)):
      im = Image.open(p)
      im = im.resize((512, 512))
      im.save(path+str(i)+'.png', 'PNG')

# %%
path='/content/dataset/images_prepped_test/'
for i in range(1,781):
    p=path+str(i)+'.png'
    if(os.path.isfile(p)):
      im = Image.open(p)
      im = im.resize((512, 512))
      im.save(path+str(i)+'.png', 'PNG')

# %%
path='/content/dataset/images_prepped_train/'
for i in range(1,781):
    p=path+str(i)+'.png'
    if(os.path.isfile(p)):
      im = Image.open(p)
      im = im.resize((512, 512))
      im.save(path+str(i)+'.png', 'PNG')

# %% [markdown]
# !git clone https://github.com/sevakon/unet-keras.git

# %%
# !git clone https://github.com/sevakon/unet-keras.git
# Out:
# Cloning into 'unet-keras'...
# remote: Enumerating objects: 224, done.
# remote: Total 224 (delta 0), reused 0 (delta 0), pack-reused 224
# Receiving objects: 100% (224/224), 538.03 KiB | 1.64 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
# !pip install pathlib

# %%
# !python /content/unet-keras/main.py
# Out:
# 2020-12-24 15:41:19.840681: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Adding paddings failed at #1
# Adding paddings failed at #2
# Adding paddings failed at #3
# Adding paddings failed at #4
# Adding paddings failed at #5
# Adding paddings failed at #6
# Adding paddings failed at #7
# Adding paddings failed at #8
# Adding paddings failed at #9
# Adding paddings failed at #10
# Adding paddings failed at #11
# Adding paddings failed at #12
# Adding paddings failed at #13
# Adding paddings failed at #14
# Adding paddings failed at #15
# Adding paddings failed at #16
# Adding paddings failed at #17
# Adding paddings failed at #18
# Adding paddings failed at #19
# Adding paddings failed at #20
# Adding paddings failed at #21
# Adding paddings failed at #22
# Adding paddings failed at #23
# Adding paddings failed at #24
# Adding paddings failed at #25
# Adding paddings failed at #26
# ...

# %%
# !python /content/unet-keras/predict.py
# Out:
# 2020-12-24 21:20:45.378303: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-24 21:20:48.024218: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2020-12-24 21:20:48.025343: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2020-12-24 21:20:48.051996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-24 21:20:48.052665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# ...
